# %%
import pandas as pd

# %%
import numpy as np

# %%
# !pip install git+https://github.com/ywu60/Combinatorial-Fusion-Analysis.git
# Out:
# Collecting git+https://github.com/ywu60/Combinatorial-Fusion-Analysis.git
#   Cloning https://github.com/ywu60/Combinatorial-Fusion-Analysis.git to /private/var/folders/kp/r8hgs3m14_x15dqrl_q1wm380000gn/T/pip-req-build-_91i7ezb
#   Running command git clone --filter=blob:none --quiet https://github.com/ywu60/Combinatorial-Fusion-Analysis.git /private/var/folders/kp/r8hgs3m14_x15dqrl_q1wm380000gn/T/pip-req-build-_91i7ezb
#   Resolved https://github.com/ywu60/Combinatorial-Fusion-Analysis.git to commit cd56ff40836ab83029b8104c31eaa70d89cc755e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: CFA
#   Building wheel for CFA (pyproject.toml) ... done
#   Created wheel for CFA: filename=cfa-0.1.0-py3-none-any.whl size=6844 sha256=32eeb47681bace7863a347cd18f6c3bedd397ba53bf7834a802ff97326d46f12
#   Stored in directory: /private/var/folders/kp/r8hgs3m14_x15dqrl_q1wm380000gn/T/pip-ephem-wheel-cache-ugf3ypv4/wheels/88/20/80/ef9415a0573bb5b05715edd11663d6e03b5d75bbb98e5d52fe
# Successfully built CFA
# Installing collected packages: CFA
#   Attempting uninstall: CFA
#     Found existing installation: CFA 0.1.0
#     Uninstalling CFA-0.1.0:
#       Successfully uninstalled CFA-0.1.0
# Successfully installed CFA-0.1.0

# %%
from cfa import cfa_single_layer, performance_plot, RSC_graph, compute_cd_ds, compute_performance

# %%
df = pd.read_csv('test_df.csv')
df.head(3)
# Out:
#           A         B         C         D             E
# 0  0.333397  0.378896  0.421560  0.309491  1.262137e-03
# 1  0.569227  0.844793  0.999568  0.833341  2.195689e-08
# 2  0.012746  0.105379  0.005150  0.007349  5.850156e-03

# %%
y_true = pd.read_csv('test_ytrue.csv')
y_true.head(4)
# Out:
#    0
# 0  0
# 1  0
# 2  0
# 3  1

# %%
fusion_df = cfa_single_layer(df, y_true, perf_metric='accuracy')
fusion_df.head(4)
# Out:
#       asc   wscds     arc   wrcds
# A  0.8945  0.8945  0.8945  0.8945
# B  0.8835  0.8835  0.8835  0.8835
# C  0.9000  0.9000  0.9000  0.9000
# D  0.9380  0.9380  0.9380  0.9380

# %%
RSC_graph(df)

# %%
import sys
print(sys.executable)
# Out:
# /Users/yuanhong/miniforge3/bin/python

# %%
# !which python
# !python -c "import sys; print(sys.executable)"
# Out:
# /Users/yuanhong/miniforge3/bin/python
# /Users/yuanhong/miniforge3/bin/python
